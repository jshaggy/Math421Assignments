# %% [markdown]
# ---
# title: "Assignment 16"
# author: "Josie Shaggy"
# date: "November 14, 2018"
# output:
#   word_document: default
#   html_document: default
# ---
#
# ```{r setup, include=FALSE}
# ```
#
#
# #1
# ```{r}
# x = rnorm(1000, 0, 1)
# a = rnorm(1000, 0, 1)
# b = rnorm(1000, 0, 1)
# c = rnorm(1000, 0, 1)
# d = rnorm(1000, 0, 1)
#
# hist(x^2 + a^2 + b^2 + c^2 + d^2)
#
# ```
#
#
# #2
#
# ```{r}
# r1 = sample(1:6, 1000, replace=TRUE)
# r2 = sample(1:6, 1000, replace=TRUE)
# r3 = sample(1:6, 1000, replace=TRUE)
#
# sum(r1>r2+r3)/1000
#
# ```
#
# #3
# ```{r}
# n=100
# u1 = runif(n, 0, 1)
# u2 = runif(n, 0, 1)
# u3 = runif(n, 0, 1)
#
# m= max(u1, u2, u3)
# sum(m>0.75)/n
# ```
#
# #4
# ```{r}
# n = 1000
# x = runif(n, -2, 2)
# y = runif(n, -3, 3)
# sum(((x^2)/4)+((y^2)/9)<1)/n
#
# ```
#
#
# #5
# ```{r}
# n = 1000
# x = runif(n, 0, 1)
# y = runif(n, 0, 1+ 1*sin(1))
#
#
#
# sum(1+ x*sin(x) > y)/n
#
# ```
#
#
#
# #6
# ```{r}
# x = runif(1000, -1, 1)
# e = rnorm(1000,0,1)
# y = 2*x+3+e
# lm(y~x)
# ```
#
#
#
# #7 s=.1
# ```{r}
# #
# x = runif(1000, -1, .1)
# e = rnorm(1000,0,.1)
# y = 2*x+3+e
# lm(y~x)
#
# ```
#
#
# #7 s=1
# ```{r}
# #
# x = runif(1000, -1, 1)
# e = rnorm(1000,0,1)
# y = 2*x+3+e
# lm(y~x)
#
# ```
#
#
# #7 s=2
# ```{r}
# #
# x = runif(1000, -1, 2)
# e = rnorm(1000,0,2)
# y = 2*x+3+e
# lm(y~x)
#
# ```
#
#
# #7 s=5
# ```{r}
# #
# x = runif(1000, -1, 5)
# e = rnorm(1000,0,5)
# y = 2*x+3+e
# lm(y~x)
#
# ```
#
#
# #7 s=10
# ```{r}
# #
# x = runif(1000, -1, 10)
# e = rnorm(1000,0,10)
# y = 2*x+3+e
# lm(y~x)
#
# ```
#
#
# #7 s=20
# ```{r}
# #
# x = runif(1000, -1, 20)
# e = rnorm(1000,0,20)
# y = 2*x+3+e
# lm(y~x)
#
# ```
#
#
# #7 s=50
# ```{r}
# #
# x = runif(1000, -1, 50)
# e = rnorm(1000,0,50)
# y = 2*x+3+e
# lm(y~x)
#
# ```
#
#
# #7 s=100
# ```{r}
# #
# x = runif(1000, -1, 100)
# e = rnorm(1000,0,100)
# y = 2*x+3+e
# lm(y~x)
#
# ```
