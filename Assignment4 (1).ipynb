# %% [markdown]
# ---
# title: "Assignment 4"
# author: "Josie Shaggy"
# date: "September 26, 2018"
# output:
#   word_document: default
#   html_document: default
# ---
# #1
# ```{r #1}
# quadraticj = function(x)
#  {
#      return(x^2+3*x+1)
# }
# quadraticj(4)
# ```
#
#
# #2
# ```{r #2}
# x=c(6,7,9,1)
# prod(x, na.rm = FALSE)
# ```
#
#
# #3
# ```{r #3 }
#
# S = c(4,5,6,NA,7,NA,9)
# S[is.na(S)] = 3
# S
# ```
#
#
# #4
# ```{r #4}
# T = c(4,5,6,NA,7,NA,9)
# T[is.na(T)] = mean(T, na.rm = TRUE)
# T
#
#
# ```
#
# #5
# ```{r #5}
# L = matrix(c(NA,2,3,1,NA,NA,8,3,NA), ncol=3)
# for (i in 1:ncol(L))
# {
# L[,i][is.na(L[,i])] = mean(L[,i], 0 + i, na.rm = TRUE)
#
# }
# L
# ```
#
#
#
# #6
# ```{r #6}
# library(ggplot2)
# F = c(1,2,4,2,4,3,1,2,5,4,3)
# dat <- data.frame(F)
# dat$F = factor(dat$F)
# ggplot(dat, aes(x = dat[,1])) + geom_bar()
# ```
#
#
# #7
# ```{r #7}
# U = c(1,2,4,2,4,3,1,2,5,4,3)
# I = c(3,5,1,7,4,3,2,3,5,1,9)
# dat <- data.frame(U)
# dat <- data.frame(I)
# dat <- data.frame(cbind(U,I))
# dat$U = factor(dat$U)
# dat$I = factor(dat$I)
# ggplot(dat, aes(x = dat[,1], fill = dat[,2])) + geom_bar()
# ```
