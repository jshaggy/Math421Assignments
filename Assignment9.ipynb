# %% [markdown]
# ---
# title: 'Assignment #9'
# author: "Josie Shaggy"
# date: "October 1, 2018"
# output:
#   word_document: default
#   html_document: default
# ---
#
# ```{r }
# titanic = read.csv("titanic.csv")
# titanic$PassengerId = NULL
# titanic$Name = NULL
# titanic$Ticket = NULL
# titanic$Cabin = NULL
# titanic$Survived = factor(titanic$Survived)
# titanic$Pclass = factor(titanic$Pclass)
#
# ```
#
#
# #1
# ```{r}
# L = matrix(c(NA,2,3,1,NA,NA,8,3,NA), ncol=3)
# q1 = function(L){
#
# for (i in 1:ncol(L))
#      {sum(is.na(L[,i]))
#       print(sum(is.na(L[,i])))}
# }
# q1(L)
#
# ```
#
# #2
# ```{r}
#
#
# L = matrix(c(NA,2,3,1,NA,NA,8,3,NA), ncol=3)
# L = data.frame(L)
#
# q2 = function(L){
#
# for (i in 1:ncol(L)){
#
#     if(sum(is.na(L[,i])!=0))
#        {
#          print(names(L)[i])
#        }
# }
# }
# q2(L)
#
# ```
#
#
# #3
# ```{r}
#
#
# L = matrix(c(NA,2,3,1,NA,NA,8,3,NA), ncol=3)
# L = data.frame(L)
#
# q3 = function(L){
#
# for (i in 1:ncol(L)){
#
#     if(sum(is.na(L[,i])!=0))
#        {
#          print((names(L)[i]))
#       print(sum(is.na(L[,i])))
#        }
# }
# }
# q3(L)
#
# ```
#
#
# #4
# ```{r}
# t1 = titanic[,-c(5,6)]
#
# Mode <- function(x) {
#      ux <- unique(x)
#      ux[which.max(tabulate(match(x, ux)))]
# }
#
#
# q4 = function(t1)
# {
#   for (i in 1:ncol(t1)){
#     if (is.numeric(t1[,i])){
#     t1[,i][is.na(t1[,i])] = mean(t1[,i], na.rm = TRUE)
#
# }else if(is.factor(t1[,i])){
#   t1[,i][is.na(t1[,i])] = Mode(t1[,i])
#
# }}
#
#   return(t1)
#   }
#
#  d1 = data.frame(matrix(c(1,2,NA, 3,4,5), ncol = 2))
#  d1$X3 = factor(c("a","a", NA))
#  d1$X4 = factor(c("a","b", NA))
#
# #q4(d1)
# d1
# q4(d1)
#
# ```
#
# #5
# ```{r}
# q5 = function(j){
#
#   j1 = c()
#   j2=c()
# for (i in 1:ncol(j)){
# if(is.numeric(j[,i] )){
# j1= append(j1,i)}
# if(is.factor(j[,i])){
# j2=append(j2,i)
# }}
#
#   r1 = j[,j1]
#   r2 = j[,j2]
#   l = list(r1, r2)
#   return(l)
#   }
#
# q5(d1)
#
# ```
#
#
# #6
# ```{r}
# library(ggplot2)
# q6 = function(r){
#
# for (i in 1:ncol(r)){
# if(is.numeric(r[,i] )){
#  print(ggplot(r)+geom_density(mapping = aes(x = r[,i])))}}
# }
# q6(t1)
# ```
#
#
# #7
# ```{r}
# library(ggplot2)
# q7 = function(r){
#
# for (i in 1:ncol(r)){
# if(is.factor(r[,i] )){
#  print(ggplot(r)+geom_bar(mapping = aes(x = r[,i])))}}
# }
# q7(t1)
# ```
#
#
#
#
# #8
# ```{r}
# library(ggplot2)
# q8 = function(t,i,j){
#
#     if(is.factor(t[,i])&is.factor(t[,j])){
#      print(ggplot(t)+geom_bar(mapping = aes(x = t[,i], fill=t[,j])))}
#   else{
#     print("Not Categorical")}}
#
# q8(t1,3,2)
# ```
#
#
# #9
# ```{r, warning= FALSE}
# library(ggplot2)
# q9 = function(t,i,j){
#
#     if(is.numeric(t[,i])&is.numeric(t[,j])){
#      print(ggplot(t)+geom_point(mapping = aes(x = t[,i], y=t[,j])))}
#   else{
#     print("Not Numeric")}}
#
# q9(t1,5,4)
#
# ```
#
#
#
# #10
# ```{r, warning=FALSE}
# library(ggplot2)
# q10 = function(t,i,j){
#
#     if(is.numeric(t[,i])&is.factor(t[,j])){
#      print(ggplot(t)+geom_density(mapping = aes(x = t[,i], color=t[,j])))}
#   else{
#     print("Columns not suitable for density graph")}}
#
# q10(t1,4,3)
#
#
# ```
#
# #11
# ```{r}
#
# q11 = function(t){
#   s = length(t)
#     for (i in (1:(s-1))){
#
#       for (j in ((i+1):s)){
#
#         if(is.factor(t[,i])&is.factor(t[,j])){
#
#      print(ggplot(t)+geom_bar(mapping = aes(x = t[,i], fill=t[,j])))}
#       }
#     }
# }
# q11(titanic)
# ```
#
#
#
#
# #12
# ```{r}
# q12 = function(t){
#   s = length(t)
#     for (i in (1:(s))){
#
#       for (j in (1:s)){
#
#         if(is.numeric(t[,i])&is.factor(t[,j])){
#      print(ggplot(t)+geom_density(mapping = aes(x = t[,i], color=t[,j])))}
#       }
#     }
# }
# q12(titanic)
#
#
#
# ```
#
#
#
# #13
# ```{r}
#
# q13 = function(t){
#   q10(t)
#   q11(t)
#   q12(t)
# }
# q13(titanic)
#
#
# ```
