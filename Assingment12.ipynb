# %% [markdown]
# ---
# title: "Assignment 12"
# author: "Josie Shaggy"
# date: "October 29, 2018"
# output:
#   word_document: default
#   html_document: default
# ---
#
# ```{r setup, include=FALSE}
# knitr::opts_chunk$set(echo = TRUE)
# library(lattice)
# library(ggplot2)
# library(caret)
# library(rpart)
# library(rattle)
# ```
#
#
#
# # Adult 1
# ```{r}
# adult = read.csv("adult.csv")
# df = read.csv("adult.csv", header = FALSE)
# colnames(adult) <- c("Age","WorkClass","Fnlwgt","Education","EducationNum","MaritalStatus","Occupation", "Relationship", "Race", "Sex", "CapitalGain", "CaptialLoss", "HoursPerWeek", "NativeCountry","Salary")
# adult[adult== " ?"]=NA
#
# Mode <- function(x) {
#      ux <- unique(x)
#      ux[which.max(tabulate(match(x, ux)))]}
#
# A12 = function(x){
#   for (i in 1:ncol(x)){
#     if (is.numeric(x[,i])){
#      preProcess_missingdata_model <- preProcess(adult, method='medianImpute')
# preProcess_missingdata_model
#
#     }else if(is.factor(x[,i])){
#       x[,i][is.na(x[,i])] = Mode(x[,i])
#     }
#   }
#   return(x)
# }
#
# adult = A12(adult)
#
# #Gets rid of ?
# l = levels(adult$WorkClass)
# l[-1]
# c("Private",l[-1])
#
# c = levels(adult$NativeCountry)
# c[-1]
# c("Nepal",c[-1])
#
# g = levels(adult$Occupation)
# g[-1]
# c("Scientist",g[-1])
#
# levels(adult$Education) = c("HighSchool","HighSchool","HighSchool","Elementary","MiddleSchool","MiddleSchool","HighSchool","UnderGrad","UnderGrad","UnderGrad","PostGrad","HighSchool","PostGrad","Elementary","UnderGrad","UnderGrad")
# levels(adult$Occupation) = c("Other","Office","Military","Labor","Office","Labor","Service","Other","Service","Service","Office","Military","Office","Office","Labor")
# levels(adult$NativeCountry) = c("Asia","Asia", "NorthAmerica","Asia","SouthAmerica","NorthAmerica","NorthAmerica","SouthAmerica","CentralAmerica","Europe","Europe","Europe","Europe","CentralAmerica","NorthAmerica","Europe", "CentralAmerica","Asia","Europe","Asia","Asia","Europe","Europe","NorthAmerica","Asia","Asia","NorthAmerica","CentralAmerica","Asia","SouthAmerica","Asia", "Europe", "Europe","NorthAmerica","Europe","Europe","Asia","Asia","Asia","NorthAmerica","NorthAmerica","Asia","Europe")
# ```
#
#
#
# # Adult 2
# ```{r}
# myGrid = expand.grid(mtry = 2, splitrule = c("gini","extratrees"),
#                      min.node.size = c(1:3))
#
# model <- train(Salary~.,data = adult, method = "ranger",
#                trControl = trainControl(method ="cv", number = 7, verboseIter = TRUE),
#                tuneGrid = myGrid)
#
# model
#
# ```
#
# # Adult 3
# ```{r}
# myGrid = expand.grid(mtry = 2, splitrule = c("gini","extratrees"),
#                      min.node.size = c(1:3))
#
# model1 <- train(Salary~.,data = adult, method = "rpart",
#                trControl = trainControl(method ="cv", number = 10, verboseIter = TRUE))
#
# model1
# ```
#
# # Adult 4
# The hyperparameters of in the random forest are:
# mtry: 2
# splitrule: gini and extratrees
# min.node.size:c(1:3)
#
#
# # Adult 5
# ```{r}
# plot(model)
#
# ```
#
#
# # Adult 6
# ```{r}
# myGrid = expand.grid(mtry = 3, splitrule = c("gini","extratrees"),
#                      min.node.size = c(1:3))
#
# model2 <- train(Salary~.,data = adult, method = "ranger",
#                trControl = trainControl(method ="cv", number = 7, verboseIter = TRUE),
#                tuneGrid = myGrid)
#
# model2
#
# ```
#
#
# # Adult 7
# ```{r}
# plot(model2)
#
# ```
# Yes, the highest accuracy in 2 was 0.83 and the highest accuracy here is 0.859
#
#
# # Adult 8
# ```{r}
# install.packages('glmnet')
# library(glmnet)
#
# myControl = trainControl(
#   method = "cv", number = 10)
#
# model4 = train(Salary~ ., adult,
#   method = "glmnet",
#   trControl = myControl)
#
# model4
#
# model5 = train(
#   Salary ~ ., adult,
#   tuneGrid = expand.grid(alpha = 0:1,
#   lambda = seq(0.0001, 1, length = 20)),
#   method = "glmnet",
#   trControl = myControl
# )
#
# model5
#
#
# ```
# I did not achieve better performance in the tuned glmnet.
#
# # Titanic 1
# ```{r}
# titanic = read.csv("titanic.csv")
# df = read.csv("titanic.csv", header = FALSE)
# titanic$Survived = factor(titanic$Survived)
# titanic$Pclass = factor(titanic$Pclass)
# titanic$Age = is.numeric(titanic$Age)
# titanic$PassengerId =  NULL
# titanic$Ticket =  NULL
# titanic$Name = NULL
# titanic$Cabin = NULL
#
# Mode <- function(x) {
#      ux <- unique(x)
#      ux[which.max(tabulate(match(x, ux)))]}
#
# A13 = function(x){
#   for (i in 1:ncol(x)){
#     if (is.numeric(x[,i])){
#      preProcess_missingdata_model <- preProcess(titanic, method='medianImpute')
# preProcess_missingdata_model
#
#     }else if(is.factor(x[,i])){
#       x[,i][is.na(x[,i])] = Mode(x[,i])
#     }
#   }
#   return(x)
# }
#
# titanic = A13(titanic)
#
# ```
#
#
# # Titanic 2
# ```{r}
# myGrid = expand.grid(mtry = 2, splitrule = c("gini","extratrees"),
#                      min.node.size = c(1:3))
#
# model6 <- train(Survived~.,data = titanic, method = "ranger",
#                trControl = trainControl(method ="cv", number = 7, verboseIter = TRUE),
#                tuneGrid = myGrid)
#
# model6
#
# ```
#
#
# # Titanic 3
# ```{r}
# myGrid = expand.grid(mtry = 2, splitrule = c("gini","extratrees"),
#                      min.node.size = c(1:3))
#
# model7 <- train(Survived~.,data = titanic, method = "rpart",
#                trControl = trainControl(method ="cv", number = 10, verboseIter = TRUE))
#
# model7
# ```
# # Titanic 4
# The hyperparameters of in the random forest are:
# mtry: 2
# splitrule: gini and extratrees
# min.node.size:c(1:3)
#
#
# # Titanic 5
# ```{r}
# plot(model6)
#
# ```
#
# # Titanic 6
# ```{r}
# myGrid = expand.grid(mtry = 3, splitrule = c("gini","extratrees"),
#                      min.node.size = c(1:3))
#
# model8 <- train(Survived~.,data = titanic, method = "ranger",
#                trControl = trainControl(method ="cv", number = 7, verboseIter = TRUE),
#                tuneGrid = myGrid)
#
# model8
#
# ```
#
# # Titanic 7
# ```{r}
# plot(model6)
#
# ```
#
# # Adult 8
# ```{r}
#
#
# myControl = trainControl(
#   method = "cv", number = 10)
#
# model9 = train(Survived~ ., titanic,
#   method = "glmnet",
#   trControl = myControl)
#
# model9
#
# model10 = train(
#   Survived ~ ., titanic,
#   tuneGrid = expand.grid(alpha = 0:1,
#   lambda = seq(0.0001, 1, length = 20)),
#   method = "glmnet",
#   trControl = myControl
# )
#
# model10
#
#
# ```
